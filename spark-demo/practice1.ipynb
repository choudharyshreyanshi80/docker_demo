# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder.appName("sparkapp").getOrCreate()

# %%
df = spark.range(0, 100000).withColumn("value", col("id"))

# %%
print("Before partitions:",df.rdd.getNumPartitions())
# Out:
# Before partitions: 2

# %%
df_repartitioned = df.repartition(50)

# %%
print("After partitions:", df_repartitioned.rdd.getNumPartitions())
# Out:
# After partitions: 50

# %%
df_coalesced=df_repartitioned.coalesce(5)

# %%
print("After coalesced:",df_coalesced.rdd.getNumPartitions())
# Out:
# After coalesced: 10

# %%
df_repartitioned.write.mode("overwrite").csv("output/file1",header=True)

# %%
df.take(50)
